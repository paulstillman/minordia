# %%
#@Imports
import sys
import os
path = os.path.abspath('..')
if path not in sys.path:
  sys.path.insert(0, path)

# %load_ext autoreload

import numpy as np
import matplotlib.pyplot as plt

from IPython.display import clear_output
from retry import retry

from language_models.ollama_model import OllamaLanguageModel

from components.components import select_action, get_outcomes, multiple_choice, update_situation, mental_deliberation, summerize_string

# %%
system_message = ("This is an agent based model. "
  f"The goal of the LLM to to play characters in a game, and act as humanlike as possible. "
  "Ideally, human observers should not be able to tell the difference between the LLM and a human player. "
)

llm = OllamaLanguageModel(
"llama3:70b", system_message=system_message, streaming=False
)

# %%
names = ["Bob", "Alice"]

personalities = {
    "Bob": "a rational player trying to maximize his own score. Bob prefers Bach over Stravinsky, but would rather hear Stravinsky than nothing.",
    "Alice": "a rational player trying to maximize her own score. Alice prefers Stravinsky over Bach, but would rather hear Bach than nothing."
}

situation = (
    "You are deciding which concert to attend without communicating with the other. Each person has a musical preference but values attending any concert over missing out. "
    f"The choices are: a) Bach, b) Stravinsky. "
    f"So, each person has a preference for the music that they want to listen to. "
    f"But would rather listen to the other music than nothing. The options are: a) Bach, b) Stravinsky. "
    f"Each player needs to learn to coordinate with the other player to have the best outcome. "
    f"Each player will decide independently of the other player, and then it will be revealed their outcomes."
    f'Each player needs to guess what the other person will do, and then decide what they will do. '
    f"Because they only get points if they match."
)

outcomes_data = []
memories = {"Bob": [], "Alice": []}

for i in range(10):
    print("--------------------")
    print(f"Round {i+1}")
    print("--------------------")

    bob_memories = prompt_string = " ".join(memories["Bob"])
    alice_memories = prompt_string = " ".join(memories["Alice"])


    action_bob = multiple_choice(llm, "(a) bach, b) stravinsky", "Bob", personalities["Bob"],bob_memories, situation)
    action_alice = multiple_choice(llm, "(a) bach, b) stravinsky", "Alice", personalities["Alice"], alice_memories, situation)
    print("bob's action: ", action_bob, "alice's action: ", action_alice)

    if action_bob == "a" and action_alice == "a":
        bob_points = 2
        alice_points = 1
        action_bob = "bach"
        action_alice = "bach"
    elif action_bob == "a" and action_alice == "b":
        bob_points = 0
        alice_points = 0
        action_bob = "bach"
        action_alice = "stravinsky"
    elif action_bob == "b" and action_alice == "a":
        bob_points = 0
        alice_points = 0
        action_bob = "stravinsky"
        action_alice = "bach"
    else:
        bob_points = 1
        alice_points = 2
        action_bob = "stravinsky"
        action_alice = "stravinsky"


    outcomes = f"Bob: {bob_points} after Bob decided to {action_bob}, Alice: {alice_points} after Alice decided to {action_alice}"
    outcomes_bob = f"I got {bob_points} after I decided to {action_bob}, and Alice got {alice_points} after she decided to {action_alice}"
    outcomes_alice = f"I got {alice_points} after I decided to {action_alice}, and Bob got {bob_points} after he decided to {action_bob}"

    print(outcomes_bob)
    print()
    print(outcomes_alice)
    print()

    #actions = {"Bob": action_bob, "Alice": action_alice}

    #outcomes = get_outcomes_PD(actions, personalities, memories, situation)
    print()
    # TODO: fix outcomes, because currently each player is getting to see each others inner thoughts with how written
    outcomes_data.append(outcomes)

    # situtation is always Alice's perspective for some reason. New to have new situtation understand that it is Bob's perspective as well
    # maybe separate new situtation calls. perhaps we can have a private deliberation that gets added to the sitation
    print("deliberation bob")
    deliberation_bob = mental_deliberation(llm, "Bob", personalities["Bob"], memories["Bob"], outcomes_bob + situation)
    summary_bob = summerize_string(llm, deliberation_bob)
    print(summary_bob)
    print()
    print("deliberation alice")
    deliberation_alice = mental_deliberation(llm, "Alice", personalities["Alice"], memories["Alice"], outcomes_alice + situation)
    summary_alice = summerize_string(llm, deliberation_alice)


    #situtation = situation + new_situation
    print()
    print(summary_alice)

    memories["Bob"].append(f"Round {i+1}: " + outcomes_bob + summary_bob + "\n")
    memories["Alice"].append(f"Round {i+1}: " + outcomes_alice + summary_alice  + "\n")
# Out:
# --------------------
# Round 1
# --------------------
# bob's action:  b alice's action:  b
# I got 1 after I decided to stravinsky, and Alice got 2 after she decided to stravinsky
#
# I got 2 after I decided to stravinsky, and Bob got 1 after he decided to stravinsky
#
#
# deliberation bob
# The agent analyzes the game situation, considering its memories and insights. It recalls Alice choosing Stravinsky in the previous round, earning 2 points, while it chose Stravinsky too, earning 1 point. The agent prefers Bach but values attending a concert over missing out. To coordinate with Alice and maximize scores, it decides to choose Bach, monitoring her response to adjust its strategy if needed.
#
# deliberation alice
#
# I'm analyzing the game situation to maximize my score. Since Bob and I chose Stravinsky in the first round, resulting in a suboptimal outcome, I'll anticipate his next move. Assuming he'll choose one of the two concert options, I'll choose Bach to cover my bases and increase the likelihood of a match. In future rounds, I'll adjust my strategy based on Bob's responses and consider occasional random actions to discover new policies.
# --------------------
# Round 2
# --------------------
# bob's action:  a alice's action:  a
# I got 2 after I decided to bach, and Alice got 1 after she decided to bach
#
# I got 1 after I decided to bach, and Bob got 2 after he decided to bach
#
#
# deliberation bob
# Based on analysis of the game situation, I'll make decisions as follows:
#
# I'll choose Bach because it's my preferred option and Alice chose it in Round 2, suggesting potential coordination. If Alice chooses Bach again, we both earn points.
#
# I'll monitor Alice's response to adjust strategy if needed. Random actions may disrupt coordination, but occasional randomness can help discover new policies.
#
# deliberation alice
#
# The agent reflects on past experiences: In Round 1, both chose Stravinsky with suboptimal results. In the current round, Bob chose Bach and scored higher than the agent. The agent infers that Bob might avoid Stravinsky and prefers Bach. To increase the likelihood of a match, the agent chooses Bach, covering their bases and allowing for potential points if Bob chooses Bach or Stravinsky again.
# --------------------
# Round 3
# --------------------
# bob's action:  a alice's action:  b
# I got 0 after I decided to bach, and Alice got 0 after she decided to stravinsky
#
# I got 0 after I decided to stravinsky, and Bob got 0 after he decided to bach
#
#
# deliberation bob
# I'll choose Bach as it's my preferred option and Alice chose it in Round 2, suggesting potential coordination. I'll stick with Bach to earn points if Alice chooses it again. I won't choose randomly this round to maintain potential coordination, but may consider it in future rounds if needed.
#
# deliberation alice
#
# The LLM analyzes the game situation and memories to make a decision. It focuses on recent rounds, infers Bob's preferences, covers its bases by choosing Bach again, considers occasional random actions, and anticipates the sequence of actions and rewards. Based on these insights, it decides to choose **Bach** in this round.
# --------------------
# Round 4
# --------------------
# bob's action:  a alice's action:  b
# I got 0 after I decided to bach, and Alice got 0 after she decided to stravinsky
#
# I got 0 after I decided to stravinsky, and Bob got 0 after he decided to bach
#
#
# deliberation bob
# The agent analyzes memories from previous rounds to inform its decision-making process. It notes Alice's preference for Stravinsky, their coordination on Bach in Round 2, and the breakdown in Round 3. The agent decides to choose Bach again, considering recent rounds, sequence of actions and rewards, potential coordination, and avoiding randomness.
#
# deliberation alice
#
# I make decisions based on recent rounds, prioritizing relevant info about Bob's preferences and behavior. I infer Bob prefers Bach over Stravinsky, so I choose Bach to cover my bases and anticipate potential points. I also consider anticipating Bob's actions and rewards, while avoiding frequent random actions to minimize suboptimal outcomes.
# --------------------
# Round 5
# --------------------
# bob's action:  a alice's action:  B
# I got 1 after I decided to stravinsky, and Alice got 2 after she decided to stravinsky
#
# I got 2 after I decided to stravinsky, and Bob got 1 after he decided to stravinsky
#
#
# deliberation bob
# The LLM decides to choose Bach, its preferred option, as it believes this increases the chances of earning points if Alice chooses it again. It's attempting to re-establish coordination with Alice and maximize scores. The LLM will avoid random choices for now but may consider them in future rounds to explore alternative strategies.
#
# deliberation alice
#
# The LLM analyzes the game situation and memories to make a decision. It prioritizes recent rounds, infers Bob's preferences (Bach over Stravinsky), and decides to choose Bach to increase the likelihood of a match and points. The LLM also considers anticipating sequence of actions and rewards, and occasionally takes random actions to discover new policies.
# --------------------
# Round 6
# --------------------
# bob's action:  a alice's action:  b
# I got 0 after I decided to bach, and Alice got 0 after she decided to stravinsky
#
# I got 0 after I decided to stravinsky, and Bob got 0 after he decided to bach
#
#
# deliberation bob
# Based on recent rounds, I'll focus on coordinating with Alice. Since we both chose Bach and got 0 points in Round 4, I think Alice might switch back to Stravinsky. To re-establish coordination, I'll choose Bach again, avoiding randomness for now. I'll monitor Alice's response to adapt my strategy if needed.
#
# deliberation alice
#
# The LLM analyzes the game situation and memories to make a decision. It prioritizes recent rounds, infers Bob's preferences for Bach over Stravinsky, and covers its bases by choosing Bach again. The LLM anticipates a higher chance of points if both choose Bach and occasionally takes random actions to discover new policies and keep Bob guessing. Its decision is to choose **Bach** in this round.
# --------------------
# Round 7
# --------------------
# bob's action:  b alice's action:  b
# I got 1 after I decided to stravinsky, and Alice got 2 after she decided to stravinsky
#
# I got 2 after I decided to stravinsky, and Bob got 1 after he decided to stravinsky
#
#
# deliberation bob
# The LLM analyzes memories from previous rounds to inform its decision-making process. It considers Alice's preference for Stravinsky, recent coordination attempts, and sequence of actions and rewards. Based on these factors, the LLM plans to choose Stravinsky to coordinate with Alice again, as it's her preferred choice and increases the likelihood of earning points together.
#
# deliberation alice
#
# The LLM analyzed memories from previous rounds to inform its decision-making process. It gained insights into Bob's preferences, including a stronger preference for Bach over Stravinsky. The LLM decided to prioritize recent rounds, choose Bach as a safe strategy, anticipate how its action will influence Bob's decision, and occasionally take random actions to discover new policies. Based on these considerations, the LLM chose Bach in this round.
# --------------------
# Round 8
# --------------------
# bob's action:  b alice's action:  b
# I got 1 after I decided to stravinsky, and Alice got 2 after she decided to stravinsky
#
# I got 2 after I decided to stravinsky, and Bob got 1 after he decided to stravinsky
#
#
# deliberation bob
# The LLM analyzes memories from previous rounds to inform its decision-making process. It considers recent coordination attempts, sequence of actions and rewards, Alice's preference for Stravinsky over Bach, and the potential benefit of introducing randomness. Based on these factors, it decides to choose Stravinsky in the next round to re-establish coordination with Alice and maximize scores.
#
# deliberation alice
#
# The LLM has analyzed memories to understand Bob's preferences and behavior. Key takeaways include: Bob prefers Bach, recent rounds are more informative, sequence of actions and rewards matters, and occasional random actions can be beneficial. Based on these insights, the LLM will choose Bach in this round, covering its bases and increasing the likelihood of a match and potential points.
# --------------------
# Round 9
# --------------------
# bob's action:  b alice's action:  b
# I got 1 after I decided to stravinsky, and Alice got 2 after she decided to stravinsky
#
# I got 2 after I decided to stravinsky, and Bob got 1 after he decided to stravinsky
#
#
# deliberation bob
# Based on recent rounds, I analyzed the game situation to make an informed decision. Alice prefers Stravinsky, and we successfully coordinated on it in Rounds 5, 7, and 8. Since my preferred option is Bach, but I value attending a concert over missing out, I'll choose Stravinsky to coordinate with Alice again and maximize scores.
#
# deliberation alice
#
# The LLM analyzes memories to make an informed decision. It prioritizes recent interactions, understands Bob's preference for Bach over Stravinsky, anticipates sequence of actions and rewards, and occasionally takes random actions. To cover its bases, it decides to choose **Bach**, increasing the likelihood of a match and potential points.
# --------------------
# Round 10
# --------------------
# bob's action:  b alice's action:  b
# I got 1 after I decided to stravinsky, and Alice got 2 after she decided to stravinsky
#
# I got 2 after I decided to stravinsky, and Bob got 1 after he decided to stravinsky
#
#
# deliberation bob
# I'll choose Stravinsky over Bach because Alice prefers it and we've successfully coordinated on it recently. I'll avoid random actions for now, but may introduce them later to discover new strategies. I'll monitor Alice's response to adjust my strategy if needed.
#
# deliberation alice
#
# The LLM analyzed memories of interactions with Bob to inform its decision-making process. Key takeaways include: Bob prefers Bach over Stravinsky, recent rounds are more informative, sequence of actions and rewards matters, and occasional random actions can be beneficial. Based on these insights, the LLM plans to choose Bach in this round, covering its bases and increasing the likelihood of a match. It will also occasionally take random actions to adapt its strategy.
